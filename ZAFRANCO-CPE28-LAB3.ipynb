# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from sklearn.datasets import make_blobs

# %%
df = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/refs/heads/master/Data%20Sets/personnel_data.csv')
df.head(3)
# Out:
#    EmployeeID  Age  Experience  EducationLevel  Salary  JobSatisfaction  \
# 0           1   50           1               2   33.07                3
# 1           2   36           4               1   19.37                7
# 2           3   29          28               1   52.64                8
#
#    Department  ProjectsHandled  PromotionLast5Years
# 0           5               10                    0
# 1           1               11                    0
# 2           1                5                    1

# %%
data = make_blobs(n_samples = 200, n_features = 2, centers = 4, cluster_std = 1.8, random_state = 101)

# data[0]
# data[0][:,0]
# data[0][:,1]

# %%
data[0].shape
# Out:
# (200, 2)

# %% [markdown]
# **Plots**

# %%
plt.scatter(data[0][:,0], data[0][:,1], c = data[1], cmap = 'rainbow') # Plotting column 1 and column 2
plt.grid()

# %% [markdown]
# **Clustering**

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = 4) # is unsupervised learning algorithms, we find labels into clusters

# %%
kmeans.fit(data[0]) # fit to features
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_ # centroid of clusters
# Out:
# array([[-9.46941837, -6.56081545],
#        [ 3.66465568,  6.97762652],
#        [-4.13591321,  7.95389851],
#        [-0.03183854,  2.07689723]])

# %%
kmeans.labels_ # shows to where a data point belongs to a cluster (find labels)
# Out:
# array([2, 1, 3, 1, 1, 0, 1, 3, 1, 3, 2, 3, 1, 1, 2, 3, 1, 3, 0, 2, 0, 3,
#        3, 0, 2, 0, 0, 3, 1, 1, 2, 0, 1, 3, 3, 2, 0, 0, 0, 3, 0, 2, 2, 2,
#        3, 1, 2, 3, 0, 3, 3, 2, 1, 3, 0, 2, 3, 3, 2, 1, 0, 1, 0, 2, 1, 3,
#        0, 1, 1, 0, 1, 3, 0, 3, 0, 1, 1, 3, 2, 3, 3, 0, 1, 0, 3, 3, 3, 2,
#        3, 0, 0, 0, 0, 3, 3, 0, 1, 2, 0, 1, 3, 0, 3, 3, 1, 3, 0, 1, 0, 0,
#        1, 2, 2, 1, 0, 1, 2, 2, 1, 2, 1, 2, 3, 2, 3, 1, 2, 3, 0, 2, 2, 2,
#        3, 0, 0, 2, 1, 2, 1, 3, 0, 1, 0, 2, 2, 1, 3, 0, 2, 2, 2, 2, 3, 1,
#        3, 2, 1, 1, 1, 3, 1, 3, 3, 2, 0, 2, 3, 1, 2, 3, 1, 3, 2, 1, 3, 2,
#        1, 1, 0, 1, 2, 0, 0, 2, 0, 0, 0, 0, 0, 3, 0, 1, 1, 2, 0, 3, 1, 1,
#        0, 3], dtype=int32)

# %%
data[1] # original labels
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %% [markdown]
# **Plot Comparisons**

# %%
fig, (ax1, ax2) = plt.subplots(1,2, sharey = True, figsize = (15,6))

ax1.set_title('K - Means')
ax1.scatter(data[0][:,0], data[0][:,1], c = kmeans.labels_, cmap = 'rainbow')
ax1.grid()

ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1], c = data[1], cmap = 'rainbow')
ax2.grid()

# %%
# 1. Without using correlational analysis, which two (2) variables do you think is safe to eliminate immediately?
df_cleaned = df.drop(['EmployeeID', 'PromotionLast5Years'], axis=1)

# %%
# Please scale the cleaned data using a StandardScaler()
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_cleaned)

# %%
# 2. What is now the scaled value for Salary of data 125?
# Find the index of the 'Salary' column after dropping
salary_col_index = df_cleaned.columns.get_loc('Salary')
scaled_salary_125 = scaled_data[125, salary_col_index]
print(f"Scaled value for Salary of data 125: {scaled_salary_125:.2f}")
# Out:
# Scaled value for Salary of data 125: 1.07

# %%
# 3. What is now the scaled value for Experience of data 130?
# Find the index of the 'Experience' column after dropping
experience_col_index = df_cleaned.columns.get_loc('Experience')
scaled_experience_130 = scaled_data[130, experience_col_index]
print(f"Scaled value for Experience of data 130: {scaled_experience_130:.2f}")
# Out:
# Scaled value for Experience of data 130: 1.10

# %%
#used random_state = 101, and n_init = 'auto' for KMeans
kmeans = KMeans(n_clusters=4, random_state=101, n_init='auto')
kmeans.fit(scaled_data)
# Out:
# KMeans(n_clusters=4, random_state=101)

# %%
# Calculate the correlation matrix
correlation_matrix = df_cleaned.corr()

# Set the correlation threshold
threshold = 0.66

# %%
# Identify highly correlated pairs (absolute value greater than threshold)
highly_correlated_pairs = {}
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname_i = correlation_matrix.columns[i]
            colname_j = correlation_matrix.columns[j]
            highly_correlated_pairs[(colname_i, colname_j)] = correlation_matrix.iloc[i, j]

# %%
# Determine which variable to eliminate based on alphabetical order
variables_to_eliminate = set()
for (var1, var2), correlation in highly_correlated_pairs.items():
    # Eliminate the variable that comes first alphabetically
    if var1 < var2:
        variables_to_eliminate.add(var1)
    else:
        variables_to_eliminate.add(var2)

# %%
print("Highly correlated pairs (absolute correlation > 0.66):")
for (var1, var2), correlation in highly_correlated_pairs.items():
    print(f"{var1} and {var2}: {correlation:.2f}")

print("\nVariable(s) to be eliminated based on alphabetical order:")
for var in sorted(list(variables_to_eliminate)):
    print(var)
# Out:
# Highly correlated pairs (absolute correlation > 0.66):
# Salary and Experience: 0.69
#
# Variable(s) to be eliminated based on alphabetical order:
# Experience

# %%
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=101, n_init='auto')
    kmeans.fit(scaled_data)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %%
# Optimal number of clusters identified from the Elbow method plot is 4.
kmeans = KMeans(n_clusters=2, random_state=101, n_init='auto')
kmeans.fit(scaled_data)
# Out:
# KMeans(n_clusters=2, random_state=101)

# %%
# Create a new DataFrame with cluster labels
df_clustered = df_cleaned.copy()
df_clustered['Cluster'] = kmeans.labels_

# Use seaborn.boxplot to create a boxplot of 'Salary' vs. the cluster labels
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='Salary', data=df_clustered)
plt.title('Salary Distribution by Cluster')
plt.grid()
plt.show()

# Use seaborn.boxplot to create a boxplot of 'Age' vs. the cluster labels
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='Age', data=df_clustered)
plt.title('Age Distribution by Cluster')
plt.grid()
plt.show()

# %%
cluster_305 = kmeans.labels_[305]
print(f"Data point 305 belongs to cluster: {cluster_305}")
# Out:
# Data point 305 belongs to cluster: 0

# %%
age_col_index = df_cleaned.columns.get_loc('Age')
salary_col_index = df_cleaned.columns.get_loc('Salary')

centroids = kmeans.cluster_centers_

age_centroids = centroids[:, age_col_index]
salary_centroids = centroids[:, salary_col_index]

print("Centroids for Age:")
print(age_centroids)
print("\nCentroids for Salary:")
print(salary_centroids)
# Out:
# Centroids for Age:
# [ 0.07524311 -0.0919638 ]
#
# Centroids for Salary:
# [-0.73409992  0.89723324]

# %%
# a. Visualize the x = Age and y = Salary points, Show Data 305 with marker of star (*), color red, Show centroids with black (X) mark.
plt.figure(figsize=(10, 6))
plt.scatter(scaled_data[:, age_col_index], scaled_data[:, salary_col_index], c=kmeans.labels_, cmap='rainbow', label='Data points')
plt.scatter(scaled_data[305, age_col_index], scaled_data[305, salary_col_index], marker='*', color='red', s=200, label='Data 305')
plt.scatter(age_centroids, salary_centroids, marker='X', color='black', s=200, label='Centroids')
plt.xlabel('Scaled Age')
plt.ylabel('Scaled Salary')
plt.title('2D Visualization of Age vs Salary with Clusters and Centroids')
plt.legend()
plt.grid()
plt.show()

# %%
# b. Visualize the x = Age, y = Salary, and z = JobSatisfaction points, Show or Trace Data 305 with black circle, using scatter_3D.
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

job_satisfaction_col_index = df_cleaned.columns.get_loc('JobSatisfaction')

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(scaled_data[:, age_col_index], scaled_data[:, salary_col_index], scaled_data[:, job_satisfaction_col_index], c=kmeans.labels_, cmap='rainbow', label='Data points')
ax.scatter(scaled_data[305, age_col_index], scaled_data[305, salary_col_index], scaled_data[305, job_satisfaction_col_index], marker='o', color='black', s=100, label='Data 305')

ax.set_xlabel('Scaled Age')
ax.set_ylabel('Scaled Salary')
ax.set_zlabel('Scaled JobSatisfaction')
ax.set_title('3D Visualization of Age, Salary, and JobSatisfaction with Clusters')
ax.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_cleaned['Age'], df_cleaned['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs Salary')
plt.grid(True)
plt.show()
